# %% [markdown]
# # MLOPT Knapsack Example

# %%
import numpy as np
import cvxpy as cp
import pandas as pd
import logging

import mlopt
from mlopt.sampling import uniform_sphere_sample
from mlopt.learners.pytorch.pytorch import PyTorchNeuralNet
from mlopt.utils import n_features, pandas2array

# %% [markdown]
# ## Generate problem data

# %%
np.random.seed(1)  # Reset random seed for reproducibility

# Variable
n = 10
x = cp.Variable(n, integer=True)

# Cost
c = np.random.rand(n)

# Weights
a = cp.Parameter(n, nonneg=True, name='a')
x_u = cp.Parameter(n, nonneg=True, name='x_u')
b = 0.5 * n

# %% [markdown]
# ## Create optimizer object

# %%
# Problem
cost = - c * x
constraints = [a * x <= b,
               0 <= x, x <= x_u]


# Define optimizer
# If you just want to remove too many messages
# change INFO to WARNING
m = mlopt.Optimizer(cp.Minimize(cost), constraints,
                    log_level=logging.INFO, verbose=True)
# Out:
# > /Users/sidereus/Dropbox/research/code/projects/learning_opt/mlopt/mlopt/problem.py(67)__init__()
#      66         # Set options
# ---> 67         self.tight_constraints = tight_constraints
#      68         self.solver_options = solver_options
# ipdb>  solver_options
# {'verbose': True, 'Method': 1}

# %% [markdown]
# ## Define training and testing parameters

# %%
# Average request
theta_bar = 2 * np.ones(2 * n)
radius = 1.0


def sample(theta_bar, radius, n=100):

    # Sample points from multivariate ball
    ndim = int(len(theta_bar)/2)
    X_a = uniform_sphere_sample(theta_bar[:ndim], radius, n=n)
    X_u = uniform_sphere_sample(theta_bar[ndim:], radius, n=n)

    df = pd.DataFrame({
        'a': list(X_a),
        'x_u': list(X_u)
        })

    return df


# Training and testing data
n_train = 1000
n_test = 100
theta_train = sample(theta_bar, radius, n=n_train)
theta_test = sample(theta_bar, radius, n=n_test)

# %% [markdown]
# ## Train predictor (Pytorch)

# %%
# Dictionary of different parameters.
# The cross validation will try all of the possible
# combinations
params = {
    'learning_rate': [0.001, 0.01, 0.1],
    'batch_size': [32],
    'n_epochs': [10]
}
m.train(theta_train, learner=mlopt.PYTORCH, params=params)
# Out:
# 100%|██████████| 1000/1000 [00:27<00:00, 36.43it/s]
# INFO:mlopt:Encoding strategies
# INFO:mlopt:Getting unique set of strategies
# INFO:mlopt:Found 43 unique strategies
# INFO:mlopt:Caching KKT solver factors for each strategy (it works only for QP-representable problems with parameters only in constraints RHS)
# 100%|██████████| 43/43 [00:01<00:00, 42.89it/s]
# INFO:mlopt:Using CPU with Pytorch
# Converting dataframe to array: 100%|██████████| 1000/1000 [00:00<00:00, 2110.54it/s]
# INFO:mlopt:Split dataset in 900 training and 100 validation
# INFO:mlopt:Train Neural Network with 3 sets of parameters, 20 inputs, 43 outputs
# INFO:mlopt:Learning Neural Network with parameters: {'learning_rate': 0.001, 'batch_size': 32, 'n_epochs': 10, 'n_hidden': 31}
# INFO:mlopt:Epoch 1/10
# 100%|██████████| 29/29 [00:00<00:00, 51.57it/s, loss=3.668]
# INFO:mlopt:- Train metrics: accuracy: 0.000 ; loss: 3.729
# INFO:mlopt:- Eval metrics: accuracy: 0.400 ; loss: 3.594
# INFO:mlopt:Epoch 2/10
# 100%|██████████| 29/29 [00:00<00:00, 95.79it/s, loss=2.838]
# INFO:mlopt:- Train metrics: accuracy: 0.375 ; loss: 3.585
# INFO:mlopt:- Eval metrics: accuracy: 0.400 ; loss: 2.157
# INFO:mlopt:Epoch 3/10
# 100%|██████████| 29/29 [00:00<00:00, 79.06it/s, loss=2.111]
# INFO:mlopt:- Train metrics: accuracy: 0.375 ; loss: 2.369
# INFO:mlopt:- Eval metrics: accuracy: 0.400 ; loss: 2.119
# INFO:mlopt:Epoch 4/10
# 100%|██████████| 29/29 [00:00<00:00, 112.55it/s, loss=2.068]
# INFO:mlopt:- Train metrics: accuracy: 0.375 ; loss: 2.246
# INFO:mlopt:- Eval metrics: accuracy: 0.490 ; loss: 2.121
# INFO:mlopt:Epoch 5/10
# 100%|██████████| 29/29 [00:00<00:00, 105.23it/s, loss=2.049]
# INFO:mlopt:- Train metrics: accuracy: 0.344 ; loss: 2.241
# INFO:mlopt:- Eval metrics: accuracy: 0.450 ; loss: 2.118
# INFO:mlopt:Epoch 6/10
# 100%|██████████| 29/29 [00:00<00:00, 104.65it/s, loss=2.039]
# INFO:mlopt:- Train metrics: accuracy: 0.406 ; loss: 2.232
# INFO:mlopt:- Eval metrics: accuracy: 0.430 ; loss: 2.113
# INFO:mlopt:Epoch 7/10
# 100%|██████████| 29/29 [00:00<00:00, 72.47it/s, loss=2.028]
# INFO:mlopt:- Train metrics: accuracy: 0.375 ; loss: 2.228
# INFO:mlopt:- Eval metrics: accuracy: 0.420 ; loss: 2.106
# INFO:mlopt:Epoch 8/10
# 100%|██████████| 29/29 [00:00<00:00, 104.95it/s, loss=2.015]
# INFO:mlopt:- Train metrics: accuracy: 0.375 ; loss: 2.221
# INFO:mlopt:- Eval metrics: accuracy: 0.420 ; loss: 2.095
# INFO:mlopt:Epoch 9/10
# 100%|██████████| 29/29 [00:00<00:00, 117.04it/s, loss=1.999]
# INFO:mlopt:- Train metrics: accuracy: 0.375 ; loss: 2.209
# INFO:mlopt:- Eval metrics: accuracy: 0.420 ; loss: 2.076
# INFO:mlopt:Epoch 10/10
# 100%|██████████| 29/29 [00:00<00:00, 129.63it/s, loss=1.980]
# INFO:mlopt:- Train metrics: accuracy: 0.375 ; loss: 2.190
# INFO:mlopt:- Eval metrics: accuracy: 0.450 ; loss: 2.048
# INFO:mlopt:Learning Neural Network with parameters: {'learning_rate': 0.01, 'batch_size': 32, 'n_epochs': 10, 'n_hidden': 31}
# INFO:mlopt:Epoch 1/10
# 100%|██████████| 29/29 [00:00<00:00, 149.59it/s, loss=2.476]
# INFO:mlopt:- Train metrics: accuracy: 0.188 ; loss: 3.724
# INFO:mlopt:- Eval metrics: accuracy: 0.430 ; loss: 3.188
# INFO:mlopt:Epoch 2/10
# 100%|██████████| 29/29 [00:00<00:00, 137.93it/s, loss=2.090]
# INFO:mlopt:- Train metrics: accuracy: 0.375 ; loss: 3.424
# INFO:mlopt:- Eval metrics: accuracy: 0.510 ; loss: 2.047
# INFO:mlopt:Epoch 3/10
# 100%|██████████| 29/29 [00:00<00:00, 160.23it/s, loss=1.855]
# INFO:mlopt:- Train metrics: accuracy: 0.500 ; loss: 2.025
# INFO:mlopt:- Eval metrics: accuracy: 0.520 ; loss: 1.941
# INFO:mlopt:Epoch 4/10
# 100%|██████████| 29/29 [00:00<00:00, 172.10it/s, loss=1.770]
# INFO:mlopt:- Train metrics: accuracy: 0.531 ; loss: 1.990
# INFO:mlopt:- Eval metrics: accuracy: 0.550 ; loss: 1.801
# INFO:mlopt:Epoch 5/10
# 100%|██████████| 29/29 [00:00<00:00, 140.85it/s, loss=1.630]
# INFO:mlopt:- Train metrics: accuracy: 0.531 ; loss: 1.871
# INFO:mlopt:- Eval metrics: accuracy: 0.650 ; loss: 1.689
# INFO:mlopt:Epoch 6/10
# 100%|██████████| 29/29 [00:00<00:00, 154.79it/s, loss=1.525]
# INFO:mlopt:- Train metrics: accuracy: 0.594 ; loss: 1.825
# INFO:mlopt:- Eval metrics: accuracy: 0.580 ; loss: 1.652
# INFO:mlopt:Epoch 7/10
# 100%|██████████| 29/29 [00:00<00:00, 157.66it/s, loss=1.493]
# INFO:mlopt:- Train metrics: accuracy: 0.594 ; loss: 1.909
# INFO:mlopt:- Eval metrics: accuracy: 0.630 ; loss: 1.622
# INFO:mlopt:Epoch 8/10
# 100%|██████████| 29/29 [00:00<00:00, 87.91it/s, loss=1.442]
# INFO:mlopt:- Train metrics: accuracy: 0.594 ; loss: 1.893
# INFO:mlopt:- Eval metrics: accuracy: 0.610 ; loss: 1.597
# INFO:mlopt:Epoch 9/10
# 100%|██████████| 29/29 [00:00<00:00, 167.92it/s, loss=1.410]
# INFO:mlopt:- Train metrics: accuracy: 0.625 ; loss: 1.823
# INFO:mlopt:- Eval metrics: accuracy: 0.600 ; loss: 1.578
# INFO:mlopt:Epoch 10/10
# 100%|██████████| 29/29 [00:00<00:00, 119.50it/s, loss=1.390]
# INFO:mlopt:- Train metrics: accuracy: 0.625 ; loss: 1.750
# INFO:mlopt:- Eval metrics: accuracy: 0.540 ; loss: 1.677
# INFO:mlopt:Learning Neural Network with parameters: {'learning_rate': 0.1, 'batch_size': 32, 'n_epochs': 10, 'n_hidden': 31}
# INFO:mlopt:Epoch 1/10
# 100%|██████████| 29/29 [00:00<00:00, 151.74it/s, loss=2.485]
# INFO:mlopt:- Train metrics: accuracy: 0.188 ; loss: 3.724
# INFO:mlopt:- Eval metrics: accuracy: 0.430 ; loss: 4.455
# INFO:mlopt:Epoch 2/10
# 100%|██████████| 29/29 [00:00<00:00, 150.81it/s, loss=2.614]
# INFO:mlopt:- Train metrics: accuracy: 0.406 ; loss: 5.654
# INFO:mlopt:- Eval metrics: accuracy: 0.320 ; loss: 2.153
# INFO:mlopt:Epoch 3/10
# 100%|██████████| 29/29 [00:00<00:00, 161.24it/s, loss=2.080]
# INFO:mlopt:- Train metrics: accuracy: 0.250 ; loss: 2.332
# INFO:mlopt:- Eval metrics: accuracy: 0.320 ; loss: 2.163
# INFO:mlopt:Epoch 4/10
# 100%|██████████| 29/29 [00:00<00:00, 148.09it/s, loss=2.072]
# INFO:mlopt:- Train metrics: accuracy: 0.250 ; loss: 2.301
# INFO:mlopt:- Eval metrics: accuracy: 0.400 ; loss: 2.163
# INFO:mlopt:Epoch 5/10
# 100%|██████████| 29/29 [00:00<00:00, 125.79it/s, loss=2.073]
# INFO:mlopt:- Train metrics: accuracy: 0.375 ; loss: 2.276
# INFO:mlopt:- Eval metrics: accuracy: 0.400 ; loss: 2.164
# INFO:mlopt:Epoch 6/10
# 100%|██████████| 29/29 [00:00<00:00, 130.47it/s, loss=2.073]
# INFO:mlopt:- Train metrics: accuracy: 0.375 ; loss: 2.273
# INFO:mlopt:- Eval metrics: accuracy: 0.400 ; loss: 2.165
# INFO:mlopt:Epoch 7/10
# 100%|██████████| 29/29 [00:00<00:00, 142.61it/s, loss=2.073]
# INFO:mlopt:- Train metrics: accuracy: 0.375 ; loss: 2.270
# INFO:mlopt:- Eval metrics: accuracy: 0.400 ; loss: 2.165
# INFO:mlopt:Epoch 8/10
# 100%|██████████| 29/29 [00:00<00:00, 161.09it/s, loss=2.074]
# INFO:mlopt:- Train metrics: accuracy: 0.375 ; loss: 2.269
# INFO:mlopt:- Eval metrics: accuracy: 0.400 ; loss: 2.165
# INFO:mlopt:Epoch 9/10
# 100%|██████████| 29/29 [00:00<00:00, 134.47it/s, loss=2.074]
# INFO:mlopt:- Train metrics: accuracy: 0.375 ; loss: 2.269
# INFO:mlopt:- Eval metrics: accuracy: 0.400 ; loss: 2.165
# INFO:mlopt:Epoch 10/10
# 100%|██████████| 29/29 [00:00<00:00, 128.39it/s, loss=2.074]
# INFO:mlopt:- Train metrics: accuracy: 0.375 ; loss: 2.269
# INFO:mlopt:- Eval metrics: accuracy: 0.400 ; loss: 2.165
# INFO:mlopt:Best parameters
# INFO:mlopt:{'learning_rate': 0.01, 'batch_size': 32, 'n_epochs': 10, 'n_hidden': 31}
# INFO:mlopt:Train neural network with best parameters
# INFO:mlopt:{'learning_rate': 0.01, 'batch_size': 32, 'n_epochs': 10, 'n_hidden': 31}
# INFO:mlopt:Learning Neural Network with parameters: {'learning_rate': 0.01, 'batch_size': 32, 'n_epochs': 10, 'n_hidden': 31}
# INFO:mlopt:Epoch 1/10
# 100%|██████████| 29/29 [00:00<00:00, 79.20it/s, loss=2.476]
# INFO:mlopt:- Train metrics: accuracy: 0.188 ; loss: 3.724
# INFO:mlopt:- Eval metrics: accuracy: 0.430 ; loss: 3.188
# INFO:mlopt:Epoch 2/10
# 100%|██████████| 29/29 [00:00<00:00, 167.38it/s, loss=2.090]
# INFO:mlopt:- Train metrics: accuracy: 0.375 ; loss: 3.424
# INFO:mlopt:- Eval metrics: accuracy: 0.510 ; loss: 2.047
# INFO:mlopt:Epoch 3/10
# 100%|██████████| 29/29 [00:00<00:00, 84.95it/s, loss=1.855]
# INFO:mlopt:- Train metrics: accuracy: 0.500 ; loss: 2.025
# INFO:mlopt:- Eval metrics: accuracy: 0.520 ; loss: 1.941
# INFO:mlopt:Epoch 4/10
# 100%|██████████| 29/29 [00:00<00:00, 108.19it/s, loss=1.770]
# INFO:mlopt:- Train metrics: accuracy: 0.531 ; loss: 1.990
# INFO:mlopt:- Eval metrics: accuracy: 0.550 ; loss: 1.801
# INFO:mlopt:Epoch 5/10
# 100%|██████████| 29/29 [00:00<00:00, 106.89it/s, loss=1.630]
# INFO:mlopt:- Train metrics: accuracy: 0.531 ; loss: 1.871
# INFO:mlopt:- Eval metrics: accuracy: 0.650 ; loss: 1.689
# INFO:mlopt:Epoch 6/10
# 100%|██████████| 29/29 [00:00<00:00, 81.63it/s, loss=1.525]
# INFO:mlopt:- Train metrics: accuracy: 0.594 ; loss: 1.825
# INFO:mlopt:- Eval metrics: accuracy: 0.580 ; loss: 1.652
# INFO:mlopt:Epoch 7/10
# 100%|██████████| 29/29 [00:00<00:00, 48.89it/s, loss=1.493]
# INFO:mlopt:- Train metrics: accuracy: 0.594 ; loss: 1.909
# INFO:mlopt:- Eval metrics: accuracy: 0.630 ; loss: 1.622
# INFO:mlopt:Epoch 8/10
# 100%|██████████| 29/29 [00:00<00:00, 92.13it/s, loss=1.442]
# INFO:mlopt:- Train metrics: accuracy: 0.594 ; loss: 1.893
# INFO:mlopt:- Eval metrics: accuracy: 0.610 ; loss: 1.597
# INFO:mlopt:Epoch 9/10
# 100%|██████████| 29/29 [00:00<00:00, 131.00it/s, loss=1.410]
# INFO:mlopt:- Train metrics: accuracy: 0.625 ; loss: 1.823
# INFO:mlopt:- Eval metrics: accuracy: 0.600 ; loss: 1.578
# INFO:mlopt:Epoch 10/10
# 100%|██████████| 29/29 [00:00<00:00, 153.91it/s, loss=1.390]
# INFO:mlopt:- Train metrics: accuracy: 0.625 ; loss: 1.750
# INFO:mlopt:- Eval metrics: accuracy: 0.540 ; loss: 1.677

# %% [markdown]
# ## Benchmark on testing dataset

# %%
results = m.performance(theta_test)
print("Accuracy: %.2f " % results[0]['accuracy'])
# Out:
# INFO:root:Performance evaluation
# INFO:root:Compute tight constraints for test set (n_jobs = 1)
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Academic license - for non-commercial use only
# INFO:gurobipy:Academic license - for non-commercial use only
# 100%|██████████| 1000/1000 [00:14<00:00, 69.91it/s]
# Converting dataframe to array: 100%|██████████| 1000/1000 [00:00<00:00, 6836.02it/s]
# INFO:root:Predict tight constraints for test set
# 100%|██████████| 1000/1000 [01:49<00:00,  9.15it/s]
# Accuracy: 98.00

# %% [markdown]
# ## Save training data

# %%
m.save_training_data("training_data.pkl", delete_existing=True)

# %% [markdown]
# ## Create new solver and train passing loaded data

# %%
m = mlopt.Optimizer(cp.Minimize(cost), constraints)
m.load_training_data("training_data.pkl")
m.train(learner=mlopt.PYTORCH, params=params)  # Train after loading samples

results = m.performance(theta_test)
print("Accuracy: %.2f " % results[0]['accuracy'])
# Out:
# INFO:root:Caching KKT solver factors for each strategy (it works only for QP-representable problems with parameters only in constraints RHS)
# 100%|██████████| 50/50 [00:00<00:00, 90.66it/s]
# INFO:root:Using CPU with Pytorch
# Converting dataframe to array: 100%|██████████| 10000/10000 [00:01<00:00, 6772.84it/s]
# INFO:root:Split dataset in 9000 training and 1000 validation
# INFO:root:Train Neural Network with 3 sets of parameters, 20 inputs, 50 outputs
# INFO:root:Learning Neural Network with parameters: {'learning_rate': 0.001, 'batch_size': 32, 'n_epochs': 10, 'n_hidden': 35}
# INFO:root:Epoch 1/10
# 100%|██████████| 282/282 [00:01<00:00, 204.66it/s, loss=2.120]
# INFO:root:- Train metrics: accuracy: 0.333 ; loss: 2.669
# INFO:root:- Eval metrics: accuracy: 0.553 ; loss: 1.697
# INFO:root:Epoch 2/10
# 100%|██████████| 282/282 [00:01<00:00, 165.72it/s, loss=1.399]
# INFO:root:- Train metrics: accuracy: 0.594 ; loss: 1.664
# INFO:root:- Eval metrics: accuracy: 0.687 ; loss: 1.336
# INFO:root:Epoch 3/10
# 100%|██████████| 282/282 [00:02<00:00, 109.19it/s, loss=1.241]
# INFO:root:- Train metrics: accuracy: 0.667 ; loss: 1.415
# INFO:root:- Eval metrics: accuracy: 0.698 ; loss: 1.230
# INFO:root:Epoch 4/10
# 100%|██████████| 282/282 [00:01<00:00, 173.25it/s, loss=1.161]
# INFO:root:- Train metrics: accuracy: 0.688 ; loss: 1.326
# INFO:root:- Eval metrics: accuracy: 0.700 ; loss: 1.177
# INFO:root:Epoch 5/10
# 100%|██████████| 282/282 [00:01<00:00, 203.38it/s, loss=1.106]
# INFO:root:- Train metrics: accuracy: 0.688 ; loss: 1.276
# INFO:root:- Eval metrics: accuracy: 0.706 ; loss: 1.134
# INFO:root:Epoch 6/10
# 100%|██████████| 282/282 [00:01<00:00, 148.64it/s, loss=1.059]
# INFO:root:- Train metrics: accuracy: 0.688 ; loss: 1.236
# INFO:root:- Eval metrics: accuracy: 0.709 ; loss: 1.086
# INFO:root:Epoch 7/10
# 100%|██████████| 282/282 [00:01<00:00, 181.02it/s, loss=1.015]
# INFO:root:- Train metrics: accuracy: 0.688 ; loss: 1.182
# INFO:root:- Eval metrics: accuracy: 0.714 ; loss: 1.041
# INFO:root:Epoch 8/10
# 100%|██████████| 282/282 [00:01<00:00, 208.36it/s, loss=0.971]
# INFO:root:- Train metrics: accuracy: 0.698 ; loss: 1.128
# INFO:root:- Eval metrics: accuracy: 0.716 ; loss: 0.997
# INFO:root:Epoch 9/10
# 100%|██████████| 282/282 [00:01<00:00, 189.19it/s, loss=0.927]
# INFO:root:- Train metrics: accuracy: 0.698 ; loss: 1.084
# INFO:root:- Eval metrics: accuracy: 0.727 ; loss: 0.932
# INFO:root:Epoch 10/10
# 100%|██████████| 282/282 [00:01<00:00, 192.59it/s, loss=0.886]
# INFO:root:- Train metrics: accuracy: 0.708 ; loss: 1.020
# INFO:root:- Eval metrics: accuracy: 0.738 ; loss: 0.873
# INFO:root:Learning Neural Network with parameters: {'learning_rate': 0.01, 'batch_size': 32, 'n_epochs': 10, 'n_hidden': 35}
# INFO:root:Epoch 1/10
# 100%|██████████| 282/282 [00:01<00:00, 141.82it/s, loss=1.543]
# INFO:root:- Train metrics: accuracy: 0.365 ; loss: 2.435
# INFO:root:- Eval metrics: accuracy: 0.510 ; loss: 1.773
# INFO:root:Epoch 2/10
# 100%|██████████| 282/282 [00:02<00:00, 140.57it/s, loss=1.412]
# INFO:root:- Train metrics: accuracy: 0.542 ; loss: 2.008
# INFO:root:- Eval metrics: accuracy: 0.706 ; loss: 1.152
# INFO:root:Epoch 3/10
# 100%|██████████| 282/282 [00:01<00:00, 170.88it/s, loss=1.193]
# INFO:root:- Train metrics: accuracy: 0.646 ; loss: 1.593
# INFO:root:- Eval metrics: accuracy: 0.717 ; loss: 1.032
# INFO:root:Epoch 4/10
# 100%|██████████| 282/282 [00:01<00:00, 184.92it/s, loss=1.131]
# INFO:root:- Train metrics: accuracy: 0.656 ; loss: 1.400
# INFO:root:- Eval metrics: accuracy: 0.706 ; loss: 1.078
# INFO:root:Epoch 5/10
# 100%|██████████| 282/282 [00:01<00:00, 189.05it/s, loss=1.107]
# INFO:root:- Train metrics: accuracy: 0.646 ; loss: 1.315
# INFO:root:- Eval metrics: accuracy: 0.735 ; loss: 0.947
# INFO:root:Epoch 6/10
# 100%|██████████| 282/282 [00:01<00:00, 174.57it/s, loss=1.039]
# INFO:root:- Train metrics: accuracy: 0.646 ; loss: 1.140
# INFO:root:- Eval metrics: accuracy: 0.729 ; loss: 0.959
# INFO:root:Epoch 7/10
# 100%|██████████| 282/282 [00:01<00:00, 181.91it/s, loss=1.010]
# INFO:root:- Train metrics: accuracy: 0.677 ; loss: 1.179
# INFO:root:- Eval metrics: accuracy: 0.719 ; loss: 1.008
# INFO:root:Epoch 8/10
# 100%|██████████| 282/282 [00:01<00:00, 201.83it/s, loss=0.985]
# INFO:root:- Train metrics: accuracy: 0.688 ; loss: 1.232
# INFO:root:- Eval metrics: accuracy: 0.668 ; loss: 1.292
# INFO:root:Epoch 9/10
# 100%|██████████| 282/282 [00:01<00:00, 183.72it/s, loss=0.977]
# INFO:root:- Train metrics: accuracy: 0.635 ; loss: 1.222
# INFO:root:- Eval metrics: accuracy: 0.705 ; loss: 1.119
# INFO:root:Epoch 10/10
# 100%|██████████| 282/282 [00:01<00:00, 198.46it/s, loss=0.947]
# INFO:root:- Train metrics: accuracy: 0.667 ; loss: 1.337
# INFO:root:- Eval metrics: accuracy: 0.638 ; loss: 1.316
# INFO:root:Learning Neural Network with parameters: {'learning_rate': 0.1, 'batch_size': 32, 'n_epochs': 10, 'n_hidden': 35}
# INFO:root:Epoch 1/10
# 100%|██████████| 282/282 [00:01<00:00, 198.23it/s, loss=1.918]
# INFO:root:- Train metrics: accuracy: 0.292 ; loss: 2.770
# INFO:root:- Eval metrics: accuracy: 0.536 ; loss: 1.850
# INFO:root:Epoch 2/10
# 100%|██████████| 282/282 [00:01<00:00, 211.77it/s, loss=2.125]
# INFO:root:- Train metrics: accuracy: 0.344 ; loss: 2.243
# INFO:root:- Eval metrics: accuracy: 0.315 ; loss: 2.145
# INFO:root:Epoch 3/10
# 100%|██████████| 282/282 [00:01<00:00, 186.97it/s, loss=2.100]
# INFO:root:- Train metrics: accuracy: 0.250 ; loss: 2.300
# INFO:root:- Eval metrics: accuracy: 0.315 ; loss: 2.146
# INFO:root:Epoch 4/10
# 100%|██████████| 282/282 [00:01<00:00, 163.16it/s, loss=2.100]
# INFO:root:- Train metrics: accuracy: 0.250 ; loss: 2.301
# INFO:root:- Eval metrics: accuracy: 0.315 ; loss: 2.146
# INFO:root:Epoch 5/10
# 100%|██████████| 282/282 [00:01<00:00, 173.61it/s, loss=2.100]
# INFO:root:- Train metrics: accuracy: 0.250 ; loss: 2.302
# INFO:root:- Eval metrics: accuracy: 0.315 ; loss: 2.147
# INFO:root:Epoch 6/10
# 100%|██████████| 282/282 [00:01<00:00, 186.09it/s, loss=2.100]
# INFO:root:- Train metrics: accuracy: 0.250 ; loss: 2.302
# INFO:root:- Eval metrics: accuracy: 0.315 ; loss: 2.147
# INFO:root:Epoch 7/10
# 100%|██████████| 282/282 [00:01<00:00, 144.81it/s, loss=2.100]
# INFO:root:- Train metrics: accuracy: 0.250 ; loss: 2.303
# INFO:root:- Eval metrics: accuracy: 0.315 ; loss: 2.147
# INFO:root:Epoch 8/10
# 100%|██████████| 282/282 [00:01<00:00, 142.85it/s, loss=2.100]
# INFO:root:- Train metrics: accuracy: 0.250 ; loss: 2.303
# INFO:root:- Eval metrics: accuracy: 0.315 ; loss: 2.148
# INFO:root:Epoch 9/10
# 100%|██████████| 282/282 [00:02<00:00, 101.15it/s, loss=2.100]
# INFO:root:- Train metrics: accuracy: 0.250 ; loss: 2.303
# INFO:root:- Eval metrics: accuracy: 0.315 ; loss: 2.148
# INFO:root:Epoch 10/10
# 100%|██████████| 282/282 [00:02<00:00, 126.95it/s, loss=2.100]
# INFO:root:- Train metrics: accuracy: 0.250 ; loss: 2.303
# INFO:root:- Eval metrics: accuracy: 0.315 ; loss: 2.148
# INFO:root:Best parameters
# INFO:root:{'learning_rate': 0.001, 'batch_size': 32, 'n_epochs': 10, 'n_hidden': 35}
# INFO:root:Train neural network with best parameters
# INFO:root:{'learning_rate': 0.001, 'batch_size': 32, 'n_epochs': 10, 'n_hidden': 35}
# INFO:root:Learning Neural Network with parameters: {'learning_rate': 0.001, 'batch_size': 32, 'n_epochs': 10, 'n_hidden': 35}
# INFO:root:Epoch 1/10
# 100%|██████████| 282/282 [00:01<00:00, 143.66it/s, loss=2.120]
# INFO:root:- Train metrics: accuracy: 0.333 ; loss: 2.669
# INFO:root:- Eval metrics: accuracy: 0.553 ; loss: 1.697
# INFO:root:Epoch 2/10
# 100%|██████████| 282/282 [00:01<00:00, 160.93it/s, loss=1.399]
# INFO:root:- Train metrics: accuracy: 0.594 ; loss: 1.664
# INFO:root:- Eval metrics: accuracy: 0.687 ; loss: 1.336
# INFO:root:Epoch 3/10
# 100%|██████████| 282/282 [00:01<00:00, 163.03it/s, loss=1.241]
# INFO:root:- Train metrics: accuracy: 0.667 ; loss: 1.415
# INFO:root:- Eval metrics: accuracy: 0.698 ; loss: 1.230
# INFO:root:Epoch 4/10
# 100%|██████████| 282/282 [00:02<00:00, 102.09it/s, loss=1.161]
# INFO:root:- Train metrics: accuracy: 0.688 ; loss: 1.326
# INFO:root:- Eval metrics: accuracy: 0.700 ; loss: 1.177
# INFO:root:Epoch 5/10
# 100%|██████████| 282/282 [00:02<00:00, 106.78it/s, loss=1.106]
# INFO:root:- Train metrics: accuracy: 0.688 ; loss: 1.276
# INFO:root:- Eval metrics: accuracy: 0.706 ; loss: 1.134
# INFO:root:Epoch 6/10
# 100%|██████████| 282/282 [00:01<00:00, 157.71it/s, loss=1.059]
# INFO:root:- Train metrics: accuracy: 0.688 ; loss: 1.236
# INFO:root:- Eval metrics: accuracy: 0.709 ; loss: 1.086
# INFO:root:Epoch 7/10
# 100%|██████████| 282/282 [00:01<00:00, 160.87it/s, loss=1.015]
# INFO:root:- Train metrics: accuracy: 0.688 ; loss: 1.182
# INFO:root:- Eval metrics: accuracy: 0.714 ; loss: 1.041
# INFO:root:Epoch 8/10
# 100%|██████████| 282/282 [00:01<00:00, 156.34it/s, loss=0.971]
# INFO:root:- Train metrics: accuracy: 0.698 ; loss: 1.128
# INFO:root:- Eval metrics: accuracy: 0.716 ; loss: 0.997
# INFO:root:Epoch 9/10
# 100%|██████████| 282/282 [00:01<00:00, 159.76it/s, loss=0.927]
# INFO:root:- Train metrics: accuracy: 0.698 ; loss: 1.084
# INFO:root:- Eval metrics: accuracy: 0.727 ; loss: 0.932
# INFO:root:Epoch 10/10
# 100%|██████████| 282/282 [00:01<00:00, 174.04it/s, loss=0.886]
# INFO:root:- Train metrics: accuracy: 0.708 ; loss: 1.020
# INFO:root:- Eval metrics: accuracy: 0.738 ; loss: 0.873
# INFO:root:Performance evaluation
# INFO:root:Compute tight constraints for test set (n_jobs = 1)
# 100%|██████████| 1000/1000 [00:19<00:00, 51.19it/s]
# Converting dataframe to array: 100%|██████████| 1000/1000 [00:00<00:00, 4369.31it/s]
# INFO:root:Predict tight constraints for test set
# 100%|██████████| 1000/1000 [02:25<00:00,  6.89it/s]
# Accuracy: 98.00

# %% [markdown]
# ## Predict single point

# %%
# Predict single point
theta = theta_test.iloc[0]
root = logging.getLogger('mlopt')
root.setLevel(logging.DEBUG)
result_single_point = m.solve(theta)
print(result_single_point)
# Out:
# Converting dataframe to array: 100%|██████████| 1/1 [00:00<00:00, 1078.78it/s]
# INFO:root:Predict optimal solution
#   0%|          | 0/1 [00:00<?, ?it/s]DEBUG:root:Solving 27 x 27 linear system A x = b
# DEBUG:root:Using KKT solver cache
# DEBUG:root:Solving 27 x 27 linear system A x = b
# DEBUG:root:Using KKT solver cache
# DEBUG:root:Solving 27 x 27 linear system A x = b
# DEBUG:root:Using KKT solver cache
# DEBUG:root:Solving 27 x 27 linear system A x = b
# DEBUG:root:Using KKT solver cache
# DEBUG:root:Solving 27 x 27 linear system A x = b
# DEBUG:root:Using KKT solver cache
# DEBUG:root:Solving 27 x 27 linear system A x = b
# DEBUG:root:Using KKT solver cache
# DEBUG:root:Solving 28 x 28 linear system A x = b
# DEBUG:root:Using KKT solver cache
# DEBUG:root:Solving 28 x 28 linear system A x = b
# DEBUG:root:Using KKT solver cache
# DEBUG:root:Solving 28 x 28 linear system A x = b
# DEBUG:root:Using KKT solver cache
# DEBUG:root:Solving 28 x 28 linear system A x = b
# DEBUG:root:Using KKT solver cache
# 100%|██████████| 1/1 [00:00<00:00,  2.52it/s]
# {'x': array([0., 1., 0., 0., 0., 0., 0., 1., 1., 0.]), 'time': 0.008311986923217773, 'strategy': Strategy
#   - Tight constraints:
#          id: elements
#           7: False
#          11: [ True False  True  True  True  True  True False False  True]
#          15: [False False False False False False False False False False]
#   - Integer variables values:
#          id: elements
#           0: [0 1 0 0 0 0 0 1 1 0], 'cost': -1.4626526947158758, 'infeasibility': 0.0, 'pred_time': 0.0011489391326904297, 'solve_time': 0.007163047790527344}

# %% [markdown]
# ## Learn directly from points (talk directly to pytorch)

# %%
y = m.y_train
X = m.X_train
learner = PyTorchNeuralNet(n_input=n_features(X),
                           n_classes=len(np.unique(y)),
                           n_best=3,
                           params=params)
# Train learner
learner.train(pandas2array(X), y)

# Predict
X_pred = X.iloc[0]
y_pred = learner.predict(pandas2array(X_pred))  # n_best most likely classes
# Out:
# INFO:root:Using CPU with Pytorch
# Converting dataframe to array: 100%|██████████| 1000/1000 [00:00<00:00, 4045.27it/s]
# INFO:root:Split dataset in 900 training and 100 validation
# INFO:root:Train Neural Network with 2 sets of parameters, 20 inputs, 43 outputs
# INFO:root:Learning Neural Network with parameters: {'learning_rate': 0.001, 'batch_size': 132, 'n_epochs': 10, 'n_hidden': 31}
# INFO:root:Epoch 1/10
# 100%|██████████| 7/7 [00:00<00:00, 120.63it/s, loss=3.698]
# INFO:root:- Train metrics: accuracy: 0.205 ; loss: 3.713
# INFO:root:- Eval metrics: accuracy: 0.320 ; loss: 3.684
# INFO:root:Epoch 2/10
# 100%|██████████| 7/7 [00:00<00:00, 182.80it/s, loss=3.630]
# INFO:root:- Train metrics: accuracy: 0.394 ; loss: 3.661
# INFO:root:- Eval metrics: accuracy: 0.320 ; loss: 3.593
# INFO:root:Epoch 3/10
# 100%|██████████| 7/7 [00:00<00:00, 92.05it/s, loss=3.522]
# INFO:root:- Train metrics: accuracy: 0.394 ; loss: 3.570
# INFO:root:- Eval metrics: accuracy: 0.320 ; loss: 3.462
# INFO:root:Epoch 4/10
# 100%|██████████| 7/7 [00:00<00:00, 122.29it/s, loss=3.355]
# INFO:root:- Train metrics: accuracy: 0.394 ; loss: 3.436
# INFO:root:- Eval metrics: accuracy: 0.320 ; loss: 3.243
# INFO:root:Epoch 5/10
# 100%|██████████| 7/7 [00:00<00:00, 86.02it/s, loss=3.075]
# INFO:root:- Train metrics: accuracy: 0.394 ; loss: 3.211
# INFO:root:- Eval metrics: accuracy: 0.320 ; loss: 2.886
# INFO:root:Epoch 6/10
# 100%|██████████| 7/7 [00:00<00:00, 91.81it/s, loss=2.643]
# INFO:root:- Train metrics: accuracy: 0.394 ; loss: 2.841
# INFO:root:- Eval metrics: accuracy: 0.320 ; loss: 2.408
# INFO:root:Epoch 7/10
# 100%|██████████| 7/7 [00:00<00:00, 54.92it/s, loss=2.206]
# INFO:root:- Train metrics: accuracy: 0.394 ; loss: 2.339
# INFO:root:- Eval metrics: accuracy: 0.320 ; loss: 2.174
# INFO:root:Epoch 8/10
# 100%|██████████| 7/7 [00:00<00:00, 86.53it/s, loss=2.127]
# INFO:root:- Train metrics: accuracy: 0.394 ; loss: 2.067
# INFO:root:- Eval metrics: accuracy: 0.320 ; loss: 2.247
# INFO:root:Epoch 9/10
# 100%|██████████| 7/7 [00:00<00:00, 79.05it/s, loss=2.130]
# INFO:root:- Train metrics: accuracy: 0.386 ; loss: 2.107
# INFO:root:- Eval metrics: accuracy: 0.420 ; loss: 2.188
# INFO:root:Epoch 10/10
# 100%|██████████| 7/7 [00:00<00:00, 89.20it/s, loss=2.071]
# INFO:root:- Train metrics: accuracy: 0.356 ; loss: 2.039
# INFO:root:- Eval metrics: accuracy: 0.320 ; loss: 2.168
# INFO:root:Learning Neural Network with parameters: {'learning_rate': 0.01, 'batch_size': 132, 'n_epochs': 10, 'n_hidden': 31}
# INFO:root:Epoch 1/10
# 100%|██████████| 7/7 [00:00<00:00, 76.23it/s, loss=3.406]
# INFO:root:- Train metrics: accuracy: 0.205 ; loss: 3.713
# INFO:root:- Eval metrics: accuracy: 0.470 ; loss: 2.570
# INFO:root:Epoch 2/10
# 100%|██████████| 7/7 [00:00<00:00, 70.72it/s, loss=2.267]
# INFO:root:- Train metrics: accuracy: 0.477 ; loss: 2.492
# INFO:root:- Eval metrics: accuracy: 0.320 ; loss: 2.176
# INFO:root:Epoch 3/10
# 100%|██████████| 7/7 [00:00<00:00, 92.51it/s, loss=2.046]
# INFO:root:- Train metrics: accuracy: 0.394 ; loss: 1.994
# INFO:root:- Eval metrics: accuracy: 0.400 ; loss: 2.164
# INFO:root:Epoch 4/10
# 100%|██████████| 7/7 [00:00<00:00, 80.60it/s, loss=2.035]
# INFO:root:- Train metrics: accuracy: 0.326 ; loss: 1.999
# INFO:root:- Eval metrics: accuracy: 0.370 ; loss: 2.150
# INFO:root:Epoch 5/10
# 100%|██████████| 7/7 [00:00<00:00, 105.09it/s, loss=2.002]
# INFO:root:- Train metrics: accuracy: 0.447 ; loss: 1.978
# INFO:root:- Eval metrics: accuracy: 0.460 ; loss: 2.118
# INFO:root:Epoch 6/10
# 100%|██████████| 7/7 [00:00<00:00, 85.10it/s, loss=1.971]
# INFO:root:- Train metrics: accuracy: 0.500 ; loss: 1.939
# INFO:root:- Eval metrics: accuracy: 0.360 ; loss: 2.112
# INFO:root:Epoch 7/10
# 100%|██████████| 7/7 [00:00<00:00, 120.01it/s, loss=1.934]
# INFO:root:- Train metrics: accuracy: 0.470 ; loss: 1.895
# INFO:root:- Eval metrics: accuracy: 0.460 ; loss: 2.066
# INFO:root:Epoch 8/10
# 100%|██████████| 7/7 [00:00<00:00, 111.98it/s, loss=1.889]
# INFO:root:- Train metrics: accuracy: 0.515 ; loss: 1.837
# INFO:root:- Eval metrics: accuracy: 0.510 ; loss: 2.015
# INFO:root:Epoch 9/10
# 100%|██████████| 7/7 [00:00<00:00, 133.82it/s, loss=1.848]
# INFO:root:- Train metrics: accuracy: 0.530 ; loss: 1.787
# INFO:root:- Eval metrics: accuracy: 0.500 ; loss: 2.045
# INFO:root:Epoch 10/10
# 100%|██████████| 7/7 [00:00<00:00, 129.23it/s, loss=1.800]
# INFO:root:- Train metrics: accuracy: 0.500 ; loss: 1.804
# INFO:root:- Eval metrics: accuracy: 0.580 ; loss: 1.998
# INFO:root:Best parameters
# INFO:root:{'learning_rate': 0.01, 'batch_size': 132, 'n_epochs': 10, 'n_hidden': 31}
# INFO:root:Train neural network with best parameters
# INFO:root:{'learning_rate': 0.01, 'batch_size': 132, 'n_epochs': 10, 'n_hidden': 31}
# INFO:root:Learning Neural Network with parameters: {'learning_rate': 0.01, 'batch_size': 132, 'n_epochs': 10, 'n_hidden': 31}
# INFO:root:Epoch 1/10
# 100%|██████████| 7/7 [00:00<00:00, 91.40it/s, loss=3.406]
# INFO:root:- Train metrics: accuracy: 0.205 ; loss: 3.713
# INFO:root:- Eval metrics: accuracy: 0.470 ; loss: 2.570
# INFO:root:Epoch 2/10
# 100%|██████████| 7/7 [00:00<00:00, 147.89it/s, loss=2.267]
# INFO:root:- Train metrics: accuracy: 0.477 ; loss: 2.492
# INFO:root:- Eval metrics: accuracy: 0.320 ; loss: 2.176
# INFO:root:Epoch 3/10
# 100%|██████████| 7/7 [00:00<00:00, 139.91it/s, loss=2.046]
# INFO:root:- Train metrics: accuracy: 0.394 ; loss: 1.994
# INFO:root:- Eval metrics: accuracy: 0.400 ; loss: 2.164
# INFO:root:Epoch 4/10
# 100%|██████████| 7/7 [00:00<00:00, 91.20it/s, loss=2.035]
# INFO:root:- Train metrics: accuracy: 0.326 ; loss: 1.999
# INFO:root:- Eval metrics: accuracy: 0.370 ; loss: 2.150
# INFO:root:Epoch 5/10
# 100%|██████████| 7/7 [00:00<00:00, 139.07it/s, loss=2.002]
# INFO:root:- Train metrics: accuracy: 0.447 ; loss: 1.978
# INFO:root:- Eval metrics: accuracy: 0.460 ; loss: 2.118
# INFO:root:Epoch 6/10
# 100%|██████████| 7/7 [00:00<00:00, 109.19it/s, loss=1.971]
# INFO:root:- Train metrics: accuracy: 0.500 ; loss: 1.939
# INFO:root:- Eval metrics: accuracy: 0.360 ; loss: 2.112
# INFO:root:Epoch 7/10
# 100%|██████████| 7/7 [00:00<00:00, 122.98it/s, loss=1.934]
# INFO:root:- Train metrics: accuracy: 0.470 ; loss: 1.895
# INFO:root:- Eval metrics: accuracy: 0.460 ; loss: 2.066
# INFO:root:Epoch 8/10
# 100%|██████████| 7/7 [00:00<00:00, 44.74it/s, loss=1.889]
# INFO:root:- Train metrics: accuracy: 0.515 ; loss: 1.837
# INFO:root:- Eval metrics: accuracy: 0.510 ; loss: 2.015
# INFO:root:Epoch 9/10
# 100%|██████████| 7/7 [00:00<00:00, 125.84it/s, loss=1.848]
# INFO:root:- Train metrics: accuracy: 0.530 ; loss: 1.787
# INFO:root:- Eval metrics: accuracy: 0.500 ; loss: 2.045
# INFO:root:Epoch 10/10
# 100%|██████████| 7/7 [00:00<00:00, 162.71it/s, loss=1.800]
# INFO:root:- Train metrics: accuracy: 0.500 ; loss: 1.804
# INFO:root:- Eval metrics: accuracy: 0.580 ; loss: 1.998
# Converting dataframe to array: 100%|██████████| 1/1 [00:00<00:00, 284.65it/s]
